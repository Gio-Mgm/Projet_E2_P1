# %%
import sys
sys.path.append("../")

import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

import numpy as np

from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

from src.functions import (
    get_df_uniques, 
    manage_major_values, 
    get_corr_pairs_thresh
)

# %%
# Loads the California housing Dataset
housing = fetch_openml(name="house_prices", as_frame=True)

# Concatenate datas into a single dataframe
data = pd.DataFrame(
    data=np.c_[housing['data'], housing['target']],
    columns=housing['feature_names'] + ['target']
)
data = data.set_index("Id")
data.head()

# Save raw datas
data.to_csv("../data/01/house_prices.csv")

del housing, data

# %%
df = pd.read_csv("../data/01/house_prices.csv", index_col="Id") 
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 1460 entries, 1.0 to 1460.0
# Columns: 80 entries, MSSubClass to target
# dtypes: float64(37), object(43)
# memory usage: 923.9+ KB

# %%
df.head(1)
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1.0        60.0       RL         65.0   8450.0   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1.0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1.0       Norm     1Fam     2Story          7.0          5.0     2003.0
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1.0        2003.0     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# Id
# 1.0       196.0        Gd        TA      PConc       Gd       TA           No
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# Id
# 1.0          GLQ       706.0          Unf         0.0      150.0        856.0
#
#     Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# Id
# 1.0    GasA        Ex          Y      SBrkr     856.0     854.0           0.0
#
#      GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# Id
# 1.0     1710.0           1.0           0.0       2.0       1.0           3.0
#
#      KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces  \
# Id
# 1.0           1.0          Gd           8.0        Typ         0.0
#
#     FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea  \
# Id
# 1.0         NaN     Attchd       2003.0          RFn         2.0       548.0
#
#     GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# Id
# 1.0         TA         TA          Y         0.0         61.0            0.0
#
#      3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  \
# Id
# 1.0        0.0          0.0       0.0    NaN   NaN         NaN      0.0
#
#      MoSold  YrSold SaleType SaleCondition    target
# Id
# 1.0     2.0  2008.0       WD        Normal  208500.0

# %%
nas = df.isna().sum()

print(nas[nas > 0].apply(lambda x: round(x / df.shape[0] * 100, 2)).sort_values(ascending=False))

del nas
# Out:
# PoolQC          99.52
# MiscFeature     96.30
# Alley           93.77
# Fence           80.75
# FireplaceQu     47.26
# LotFrontage     17.74
# GarageType       5.55
# GarageYrBlt      5.55
# GarageFinish     5.55
# GarageQual       5.55
# GarageCond       5.55
# BsmtExposure     2.60
# BsmtFinType2     2.60
# BsmtFinType1     2.53
# BsmtCond         2.53
# BsmtQual         2.53
# MasVnrArea       0.55
# MasVnrType       0.55
# Electrical       0.07
# dtype: float64

# %%
get_df_uniques(df).sort_values(by=["Uniques count"])
# Out:
#          Features    Dtype  Uniques count  \
# 4          Street   object              2
# 5           Alley   object              2
# 8       Utilities   object              2
# 40     CentralAir   object              2
# 49       HalfBath  float64              3
# 64     PavedDrive   object              3
# 47   BsmtHalfBath  float64              3
# 10      LandSlope   object              3
# 71         PoolQC   object              3
# 59   GarageFinish   object              3
# 26      ExterQual   object              4
# 52    KitchenQual   object              4
# 24     MasVnrType   object              4
# 31   BsmtExposure   object              4
# 72          Fence   object              4
# 73    MiscFeature   object              4
# 29       BsmtQual   object              4
# 55     Fireplaces  float64              4
# 46   BsmtFullBath  float64              4
# 7     LandContour   object              4
# 6        LotShape   object              4
# 48       FullBath  float64              4
# 51   KitchenAbvGr  float64              4
# 30       BsmtCond   object              4
# 60     GarageCars  float64              5
# 56    FireplaceQu   object              5
# 62     GarageQual   object              5
# 63     GarageCond   object              5
# 41     Electrical   object              5
# 39      HeatingQC   object              5
# 27      ExterCond   object              5
# 1        MSZoning   object              5
# 76         YrSold  float64              5
# 9       LotConfig   object              5
# 14       BldgType   object              5
# 20      RoofStyle   object              6
# 38        Heating   object              6
# 78  SaleCondition   object              6
# 28     Foundation   object              6
# 57     GarageType   object              6
# 34   BsmtFinType2   object              6
# 32   BsmtFinType1   object              6
# 54     Functional   object              7
# 70       PoolArea  float64              8
# 50   BedroomAbvGr  float64              8
# 15     HouseStyle   object              8
# 13     Condition2   object              8
# 21       RoofMatl   object              8
# 77       SaleType   object              9
# 12     Condition1   object              9
# 17    OverallCond  float64              9
# 16    OverallQual  float64             10
# 75         MoSold  float64             12
# 53   TotRmsAbvGrd  float64             12
# 0      MSSubClass  float64             15
# 22    Exterior1st   object             15
# 23    Exterior2nd   object             16
# 68      3SsnPorch  float64             20
# 74        MiscVal  float64             21
# 44   LowQualFinSF  float64             24
# 11   Neighborhood   object             25
# 19   YearRemodAdd  float64             61
# 69    ScreenPorch  float64             76
# 58    GarageYrBlt  float64             97
# 2     LotFrontage  float64            110
# 18      YearBuilt  float64            112
# 67  EnclosedPorch  float64            120
# 35     BsmtFinSF2  float64            144
# 66    OpenPorchSF  float64            202
# 65     WoodDeckSF  float64            274
# 25     MasVnrArea  float64            327
# 43       2ndFlrSF  float64            417
# 61     GarageArea  float64            441
# 33     BsmtFinSF1  float64            637
# 79         target  float64            663
# 37    TotalBsmtSF  float64            721
# 42       1stFlrSF  float64            753
# 36      BsmtUnfSF  float64            780
# 45      GrLivArea  float64            861
# 3         LotArea  float64           1073
#
#                                                Values
# 4                                        [Pave, Grvl]
# 5                                   [nan, Grvl, Pave]
# 8                                    [AllPub, NoSeWa]
# 40                                             [Y, N]
# 49                                    [1.0, 0.0, 2.0]
# 64                                          [Y, N, P]
# 47                                    [0.0, 1.0, 2.0]
# 10                                    [Gtl, Mod, Sev]
# 71                                  [nan, Ex, Fa, Gd]
# 59                               [RFn, Unf, Fin, nan]
# 26                                   [Gd, TA, Ex, Fa]
# 52                                   [Gd, TA, Ex, Fa]
# 24                [BrkFace, None, Stone, BrkCmn, nan]
# 31                              [No, Gd, Mn, Av, nan]
# 72                    [nan, MnPrv, GdWo, GdPrv, MnWw]
# 73                      [nan, Shed, Gar2, Othr, TenC]
# 29                              [Gd, TA, Ex, nan, Fa]
# 55                               [0.0, 1.0, 2.0, 3.0]
# 46                               [1.0, 0.0, 2.0, 3.0]
# 7                                [Lvl, Bnk, Low, HLS]
# 6                                [Reg, IR1, IR2, IR3]
# 48                               [2.0, 1.0, 3.0, 0.0]
# 51                               [1.0, 2.0, 3.0, 0.0]
# 30                              [TA, Gd, nan, Fa, Po]
# 60                          [2.0, 3.0, 1.0, 0.0, 4.0]
# 56                          [nan, TA, Gd, Fa, Ex, Po]
# 62                          [TA, Fa, Gd, nan, Ex, Po]
# 63                          [TA, Fa, nan, Gd, Po, Ex]
# 41             [SBrkr, FuseF, FuseA, FuseP, Mix, nan]
# 39                               [Ex, Gd, TA, Fa, Po]
# 27                               [TA, Gd, Fa, Po, Ex]
# 1                           [RL, RM, C (all), FV, RH]
# 76           [2008.0, 2007.0, 2006.0, 2009.0, 2010.0]
# 9                 [Inside, FR2, Corner, CulDSac, FR3]
# 14              [1Fam, 2fmCon, Duplex, TwnhsE, Twnhs]
# 20         [Gable, Hip, Gambrel, Mansard, Flat, Shed]
# 38              [GasA, GasW, Grav, Wall, OthW, Floor]
# 78  [Normal, Abnorml, Partial, AdjLand, Alloca, Fa...
# 28         [PConc, CBlock, BrkTil, Wood, Slab, Stone]
# 57  [Attchd, Detchd, BuiltIn, CarPort, nan, Basmen...
# 34                [Unf, BLQ, nan, ALQ, Rec, LwQ, GLQ]
# 32                [GLQ, ALQ, Unf, Rec, BLQ, nan, LwQ]
# 54            [Typ, Min1, Maj1, Min2, Mod, Maj2, Sev]
# 70  [0.0, 512.0, 648.0, 576.0, 555.0, 480.0, 519.0...
# 50           [3.0, 4.0, 1.0, 2.0, 0.0, 5.0, 6.0, 8.0]
# 15  [2Story, 1Story, 1.5Fin, 1.5Unf, SFoyer, SLvl,...
# 13  [Norm, Artery, RRNn, Feedr, PosN, PosA, RRAn, ...
# 21  [CompShg, WdShngl, Metal, WdShake, Membran, Ta...
# 77  [WD, New, COD, ConLD, ConLI, CWD, ConLw, Con, ...
# 12  [Norm, Feedr, PosN, Artery, RRAe, RRNn, RRAn, ...
# 17      [5.0, 8.0, 6.0, 7.0, 4.0, 2.0, 3.0, 9.0, 1.0]
# 16  [7.0, 6.0, 8.0, 5.0, 9.0, 4.0, 10.0, 3.0, 1.0,...
# 75  [2.0, 5.0, 9.0, 12.0, 10.0, 8.0, 11.0, 4.0, 1....
# 53  [8.0, 6.0, 7.0, 9.0, 5.0, 11.0, 4.0, 10.0, 12....
# 0   [60.0, 20.0, 70.0, 50.0, 190.0, 45.0, 90.0, 12...
# 22  [VinylSd, MetalSd, Wd Sdng, HdBoard, BrkFace, ...
# 23  [VinylSd, MetalSd, Wd Shng, HdBoard, Plywood, ...
# 68  [0.0, 320.0, 407.0, 130.0, 180.0, 168.0, 140.0...
# 74  [0.0, 700.0, 350.0, 500.0, 400.0, 480.0, 450.0...
# 44  [0.0, 360.0, 513.0, 234.0, 528.0, 572.0, 144.0...
# 11  [CollgCr, Veenker, Crawfor, NoRidge, Mitchel, ...
# 19  [2003.0, 1976.0, 2002.0, 1970.0, 2000.0, 1995....
# 69  [0.0, 176.0, 198.0, 291.0, 252.0, 99.0, 184.0,...
# 58  [2003.0, 1976.0, 2001.0, 1998.0, 2000.0, 1993....
# 2   [65.0, 80.0, 68.0, 60.0, 84.0, 85.0, 75.0, nan...
# 18  [2003.0, 1976.0, 2001.0, 1915.0, 2000.0, 1993....
# 67  [0.0, 272.0, 228.0, 205.0, 176.0, 87.0, 172.0,...
# 35  [0.0, 32.0, 668.0, 486.0, 93.0, 491.0, 506.0, ...
# 66  [61.0, 0.0, 42.0, 35.0, 84.0, 30.0, 57.0, 204....
# 65  [0.0, 298.0, 192.0, 40.0, 255.0, 235.0, 90.0, ...
# 25  [196.0, 0.0, 162.0, 350.0, 186.0, 240.0, 286.0...
# 43  [854.0, 0.0, 866.0, 756.0, 1053.0, 566.0, 983....
# 61  [548.0, 460.0, 608.0, 642.0, 836.0, 480.0, 636...
# 33  [706.0, 978.0, 486.0, 216.0, 655.0, 732.0, 136...
# 79  [208500.0, 181500.0, 223500.0, 140000.0, 25000...
# 37  [856.0, 1262.0, 920.0, 756.0, 1145.0, 796.0, 1...
# 42  [856.0, 1262.0, 920.0, 961.0, 1145.0, 796.0, 1...
# 36  [150.0, 284.0, 434.0, 540.0, 490.0, 64.0, 317....
# 45  [1710.0, 1262.0, 1786.0, 1717.0, 2198.0, 1362....
# 3   [8450.0, 9600.0, 11250.0, 9550.0, 14260.0, 141...

# %%
df = manage_major_values(df, 90, drop=True)

# %%
get_corr_pairs_thresh(df, 20, .7)
# Out:
# 0.88248 ('GarageArea', 'GarageCars')
# 0.82567 ('GarageYrBlt', 'YearBuilt')
# 0.82549 ('TotRmsAbvGrd', 'GrLivArea')
# 0.81953 ('TotalBsmtSF', '1stFlrSF')
# 0.79098 ('target', 'OverallQual')
# 0.70862 ('target', 'GrLivArea')

# %%
df["Garage"] = df["GarageType"].notna()
df['Fence'] = df['Fence'].notna()
df['Basement'] = df["TotalBsmtSF"] > 0
df['2ndFloor'] = df["2ndFlrSF"] > 0

# create the new variable 'age'
df['Age'] = df.apply(lambda x: x['YrSold']-x['YearBuilt'] if (x['YearBuilt'] < x['YearRemodAdd'])
                         else (x['YrSold']-x['YearRemodAdd']), axis=1)

# Delete all df with MSZoning = commercial, agriculture and industrial as these are not residential units
df = df[(df.MSZoning != 'C (all)') & (
    df.MSZoning != 'I (all)') & (df.MSZoning != 'A (agr)')]

# Delete abnormal sales
df = df[(df.SaleCondition != 'Abnorml')]
df = df[(df.SaleCondition != 'Family')]

# %%
drop_columns = [
    'GarageType',
    'GarageYrBlt',
    'GarageFinish',
    'GarageCars',
    'GarageArea',
    'GarageQual',
    'YrSold',
    'YearBuilt',
    'YearRemodAdd',
    'TotalBsmtSF',
    '1stFlrSF',
    '2ndFlrSF',
    'BsmtFinSF1',
    'BsmtFinSF2',
    'TotRmsAbvGrd',
    'PoolQC',
    'MiscFeature',
    'Alley'
]

df = df.drop(drop_columns, axis=1)

del drop_columns

# %%
get_corr_pairs_thresh(df, 5, .5)
# Out:
# 0.79483 ('target', 'OverallQual')
# 0.70811 ('GrLivArea', 'target')
# 0.62998 ('GrLivArea', 'FullBath')
# 0.59422 ('OverallQual', 'GrLivArea')
# 0.58019 ('2ndFloor', 'HalfBath')

# %%
kept_cols = [
    'Age', 
    'GrLivArea', 
    'LotFrontage',
    'LotArea',  
    'Fence', 
    '2ndFloor',
    'Basement',
    'Garage',
    'target'
]

df = df[kept_cols]
cat_cols = df.select_dtypes(include='bool').columns.tolist()
num_cols = df.select_dtypes(exclude='bool').columns.tolist()
df[cat_cols] = df[cat_cols].astype("category")
df[num_cols] = df[num_cols].apply(pd.to_numeric)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 1334 entries, 1.0 to 1460.0
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          1334 non-null   float64
#  1   GrLivArea    1334 non-null   float64
#  2   LotFrontage  1094 non-null   float64
#  3   LotArea      1334 non-null   float64
#  4   Fence        1334 non-null   category
#  5   2ndFloor     1334 non-null   category
#  6   Basement     1334 non-null   category
#  7   Garage       1334 non-null   category
#  8   target       1334 non-null   float64
# dtypes: category(4), float64(5)
# memory usage: 68.2 KB

# %%
Y = df['target']
X = df.drop('target', axis=1)
print(X.head())

X.corrwith(Y)
# Out:
#       Age  GrLivArea  LotFrontage  LotArea  Fence 2ndFloor Basement Garage
# Id
# 1.0   5.0     1710.0         65.0   8450.0  False     True     True   True
# 2.0  31.0     1262.0         80.0   9600.0  False    False     True   True
# 3.0   7.0     1786.0         68.0  11250.0  False     True     True   True
# 5.0   8.0     2198.0         84.0  14260.0  False     True     True   True
# 6.0  16.0     1362.0         85.0  14115.0   True     True     True   True
# Age           -0.518485
# GrLivArea      0.708111
# LotFrontage    0.346440
# LotArea        0.264694
# dtype: float64

# %%
df.to_csv("../data/02/cleaned_house_prices.csv")

# %%
df = pd.read_csv("../data/02/cleaned_house_prices.csv", index_col="Id")
df.head()
# Out:
#       Age  GrLivArea  LotFrontage  LotArea  Fence  2ndFloor  Basement  Garage  \
# Id
# 1.0   5.0     1710.0         65.0   8450.0  False      True      True    True
# 2.0  31.0     1262.0         80.0   9600.0  False     False      True    True
# 3.0   7.0     1786.0         68.0  11250.0  False      True      True    True
# 5.0   8.0     2198.0         84.0  14260.0  False      True      True    True
# 6.0  16.0     1362.0         85.0  14115.0   True      True      True    True
#
#        target
# Id
# 1.0  208500.0
# 2.0  181500.0
# 3.0  223500.0
# 5.0  250000.0
# 6.0  143000.0

# %%
# Select Features
X = df[['Age', 'GrLivArea', 'LotFrontage',
          'LotArea', 'GarageArea', 'Fence', 'Pool']]
Y = df[['target']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_64153/3771124572.py in <module>
#       1 # Select Features
# ----> 2 X = df[['Age', 'GrLivArea', 'LotFrontage',
#       3           'LotArea', 'GarageArea', 'Fence', 'Pool']]
#       4 Y = df[['target']]
#
# ~/anaconda3/envs/e2p1/lib/python3.10/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~/anaconda3/envs/e2p1/lib/python3.10/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~/anaconda3/envs/e2p1/lib/python3.10/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['GarageArea', 'Pool'] not in index"

# %%
num_cols = df.select_dtypes(include=[np.number])
cat_cols = df.select_dtypes(include=["O"])

# %%
df.describe(include=['O'])
# Out:
#        MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# count      1334   1334     1334        1334      1334      1334      1334
# unique        4      2        4           4         1         5         3
# top          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# freq       1067   1330      837        1201      1334       967      1267
#
#        Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle  \
# count          1334       1334       1334     1334       1334      1334
# unique           25          9          8        5          8         6
# top           NAmes       Norm       Norm     1Fam     1Story     Gable
# freq            198       1152       1321     1116        660      1037
#
#        RoofMatl Exterior1st Exterior2nd MasVnrType ExterQual ExterCond  \
# count      1334        1334        1334       1326      1334      1334
# unique        8          14          16          4         4         5
# top     CompShg     VinylSd     VinylSd       None        TA        TA
# freq       1311         485         476        781       808      1174
#
#        Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2  \
# count        1334     1298     1298         1297         1298         1297
# unique          6        4        4            4            6            6
# top         PConc       Gd       TA           No          GLQ          Unf
# freq          613      584     1197          861          395         1149
#
#        Heating HeatingQC CentralAir Electrical KitchenQual Functional  \
# count     1334      1334       1334       1333        1334       1334
# unique       6         5          2          4           4          6
# top       GasA        Ex          Y      SBrkr          TA        Typ
# freq      1305       694       1254       1227         655       1243
#
#        FireplaceQu PavedDrive SaleType SaleCondition
# count          724       1334     1334          1334
# unique           5          3        8             4
# top             Gd          Y       WD        Normal
# freq           362       1227     1175          1194
